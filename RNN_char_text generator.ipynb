# %% [markdown]
# # Code for the post
#
# Code is from below links with minor changes made for the blog post.
#
# References:
#     https://gist.github.com/karpathy/d4dee566867f8291f086
#
#     https://gist.github.com/satyajitvg/9a5f782ccef5ff81f7f9863b62218b06

# %%
import numpy as np

def random_init(num_rows, num_cols):
    return np.random.rand(num_rows, num_cols)*0.01

def zero_init(num_rows, num_cols):
    return np.zeros((num_rows, num_cols))

class DataReader:
    def __init__(self, path, seq_length):
        self.fp = open(path, "r")
        #self.data = "some really long text to test this. maybe not perfect but should get you going."#self.fp.read()
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %%
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = random_init(hidden_size, vocab_size) # input to hidden
        self.W = random_init(hidden_size, hidden_size) # hidden to hidden
        self.V = random_init(vocab_size, hidden_size) # hidden to output
        self.b = zero_init(hidden_size, 1) # bias for hidden layer
        self.c = zero_init(vocab_size, 1) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = zero_init(self.vocab_size,1)
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap
        
    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity 
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc
    
    def loss(self, ps, targets):
            """loss for a sequence"""
            # calculate cross-entrpy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
        
    
    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
                
    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = zero_init(self.vocab_size, 1)
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = zero_init(self.vocab_size,1)
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 0.01
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                if not iter_num%500:
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):

        #initialize input vector
        x = zero_init(self.vocab_size, 1)
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = zero_init(self.vocab_size,1)
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 25
#read text from the "input.txt" file
data_reader = DataReader("input.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# efoorlotxaymt.tlextg to lycllroolrtmd grny aetrbtrld met lytntmt. gap tdldaisontllaggoa  saxyomxgdc  grtetxtegoebtunu ypxbb.tresroxemtn nlxs ogoeut ugoirrleyram rsno .reypsegetcroeoroboabem xerol lfot
#
#
# iter :0, loss:77.276060
# fdbaddnmd.cphssfddrib.rpxlpumaolpudsulamlpyipubdtbdhdd.cdulafndpnsaephrsxryxia.xdhd armuxbmnsprmulp.naanaul iccplcafdads.lfamfumpmlaammmmcfxsflmadmanbxr.andurxhcs.smmlcmnp.dpurburbhrcmrbfmmdb urmpmsfl
#
#
# iter :500, loss:69.476174
#  tooou t lyyieeralbots.oipect noneabep bot to t lou to to eylhi pessnept pe go sest nou on t iuhohisun pn yoopxugoooxpxt tenot tobto shngo .o goouu te aobpese buu go t  go to gomapby lyeeslyou aycst .
#
#
# iter :1000, loss:52.577288
# o terfest yong text to test mally t gep not to test yonlut tect not goie not goit yong gext t t. maybe not seit you pect but to to t but goigint thishis. maybe not goig nshould ge ret you pect not goi
#
#
# iter :1500, loss:36.617771
# t yong text to t but perfectes. mso test you goixt should get nou sh goit yong tet you should get this. maybe maybe nht perfect but perfect be not to test you goixt should get youg text to test tu you
#
#
# iter :2000, loss:24.450577
#  tebt maybe not perfect but su t but should get you goit yong tea lou should get you goie ny longot perfect bshigoit this. maybe not shoulrot perfect but shouleallylly lou ghie not perfect this. maybe
#
#
# iter :2500, loss:15.716677
# hould get you goit ysyshis. maybe lou should get you goixt perfect but should gefeyot should get you goixt should get you goixt should get yyyoureally long text to test this. mshould get you goixt sho
#
#
# iter :3000, loss:10.004135
# xt shoe not pect but should get you goit youould get you goit you goit you goixt should get you goixt should get you goixt should get you goixt should gst long text to test this. tayne long text to te
#
#
# iter :3500, loss:6.378267
#  test this. maybe not perfect but should get you goixt ou goixt should get you goit you goixt should get you goie not perfect xt you goit you goit you goixt should get you goixt should get this. maybe
#
#
# iter :4000, loss:4.094075
# hould get you goixt should get you goit you goixt should get you goixt should get you goixt should get you goit you goixt should get you goit you goixt should get you goit you goixt perfect but should
#
#
# iter :4500, loss:2.660349
# xt should get you goixt should get you goixt should get you goixt should get you goit you goit you goie not perfect but goially long text to terfect but should get you goit you goixt should get you go
#
#
# iter :5000, loss:1.761343
#  to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goit you goie not perfect but should get you goit you should get you goixt should get you g
#
#
# iter :5500, loss:1.194790
# hould get you goct but should eet you goixt should get you goie not perfect but should get you goixt should get you goig you goixt should get you goixt should get you goixt should get you goixt should
#
#
# iter :6000, loss:0.835692
# t you goie not perfect but should get you goixt should get you goixt should get you goit you goixt should get but should get you goie not perfect this. maybe not perfect but should get you goixt shoul
#
#
# iter :6500, loss:0.606006
#  to test this. maybe not perfect but sooeliot goially long text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should
#
#
# iter :7000, loss:0.456838
# est this. maybe not perfect but should get you goit you goit you goixt should get you goixt should get you goi really long text to teg text to test you goixt should get you goixt should get you goixt
#
#
# iter :7500, loss:0.357746
# xt should get you goixt should get you should get you goie not perfect but should get you goi really long text to test this. maybe not perfect this. maybennot perfect but should get you goixt should g
#
#
# iter :8000, loss:0.290896
#  te test this. maybelnong text to test this. maybe not perfect but should get you goie not perfect but should get you goit you goixt should get you goit you goixt should get you goially long text to t
#
#
# iter :8500, loss:0.244776
# hould get you goie not perfect but should get you goig you goie not perfect but should get you goiallong text to test this. maybe not perfect but should get you goixt should get you goit you goie not
#
#
# iter :9000, loss:0.212018
# xt should get you goie not perfect but should get you goit you goixt should get you goixt should get you goi teally long text to test this. maybe not perfect but should get you goie not perfect thts.
#
#
# iter :9500, loss:0.188066
#  test this. maybe not perfect but should get you goixt should get you goixt should get you goit you goit you goie not perfect but should get you goi. mally long text to test this. maybe not perfect bu
#
#
# iter :10000, loss:0.169917
# hould get you goit you goixt should get you goixt should ret you goixt should get you goi text to test this. maybe not perfect but should get you goixt should get you goiallong text to test this. mayb
#
#
# iter :10500, loss:0.155565
# xt should get you goixt should get you goixt should get you goixt should get you goixt perfect but should get you goixt should get you goixt should get you goit this. maybe not perfect but should get
#
#
# iter :11000, loss:0.143916
#  test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you g
#
#
# iter :11500, loss:0.134214
# hould get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goit you goixt should get you goit you goit you
#
#
# iter :12000, loss:0.126009
# t you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goie not perfect this. maybe not perfect but should get you goixt should get you
#
#
# iter :12500, loss:0.118948
#  test this. maybe not perfect but should get yoo goixt should get you goig you goixt should get you goit you goihis. maybe not perfect but should get you goixt should get you goixt should get you goix
#
#
# iter :13000, loss:0.112747
# hould get you goixt should get you goit you goie not perfect but should get you goit you goixt perfect but should get you goie not perfect but should get you goit you goixt should get you goie not per
#
#
# iter :13500, loss:0.107227
# xt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goit you goie not perfect but should get you go
#
#
# iter :14000, loss:0.102286
#  test this.oiaybe not perfect but should get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goixt should
#
#
# iter :14500, loss:0.097798
# est this. maybe not perfect but should get you goixt should gst you goie not perfect but should get you goie not perfect but should get you goit you goie not perfect but should get you goie not perfec
#
#
# iter :15000, loss:0.093659
# t you goixt should get you goit you goie not perfect but should get you goixt should get you goit you goixt should get you goit you goie not perfect but should get you goit you goit you goixt perfect
#
#
# iter :15500, loss:0.089826
#  test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goixt should get you goixt should get you goixt should get you goixt shou
#
#
# iter :16000, loss:0.086245
# hbut should get you goixt should get you goit you goixt should get you goie not perfect but should get you goie not perfed really long text to test this. maybe not perfect but should get you goixt sho
#
#
# iter :16500, loss:0.082890
# t you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you go
#
#
# iter :17000, loss:0.079769
#  test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goit you goie no
#
#
# iter :17500, loss:0.076854
# hould get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but
#
#
# iter :18000, loss:0.074122
# t you goixt should get you goie not perfect but should get you goit you goixt should get you goie not perfect but should get you goit you goie not perfect but should get you goixt should get you goit
#
#
# iter :18500, loss:0.071578
#  test this. maybe not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect
#
#
# iter :19000, loss:0.069195
# ect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt  u goixt should get you goixt should get you goie not perfect but should get y
#
#
# iter :19500, loss:0.066953
# t you goie not perfect but should get you goixt should get you goi. not perfect but should get you goie not perfect but should get you goie not perfect but should get you goi text to test this. maybe
#
#
# iter :20000, loss:0.064856
#  te test this. maybe not perfectest this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perf
#
#
# iter :20500, loss:0.062880
# hould get you goixt should get you goie not perfect but should get you goit you goit tu mallhnst you goit you goixt should get you goie not perfect but should get you goie not perfect but should get y
#
#
# iter :21000, loss:0.061010
# t you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should g
#
#
# iter :21500, loss:0.059250
#  test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goit you goit you goie not perfect but should get you goix
#
#
# iter :22000, loss:0.057583
# ng text to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should
#
#
# iter :22500, loss:0.055995
# t you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfe
#
#
# iter :23000, loss:0.054494
#  test this. maybe not perfect but should get you goixt should get you goist should get you goixt should get you goixt should get you goie not perfect but should get you goit you goie not perfect but s
#
#
# iter :23500, loss:0.053063
# ng text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goixt pect but should get you goixt should get you goie not perfect but should get y
#
#
# iter :24000, loss:0.051693
# xt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goit you goie not perfect but should get you goie not perfect but should get you goie not
#
#
# iter :24500, loss:0.050390
#  tect but should get you goit you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get this. maybe not perfect but should get
#
#
# iter :25000, loss:0.049143
# ect but should get you goixt should get you goixt should get you goie not perfect but should get you goixt should get you goig you goixt perfect but should get you goit you goie not perfect but should
#
#
# iter :25500, loss:0.047945
# to test this. maybe not perfect but should get you goie not perfect but shourd get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie
#
#
# iter :26000, loss:0.046805
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goiut should get you goie not perfect but should get you goixt should get yo
#
#
# iter :26500, loss:0.045715
# hould get you goixt should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should ge
#
#
# iter :27000, loss:0.044666
# t you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goi text to test thie. maybe
#
#
# iter :27500, loss:0.043667
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfene not perfect but should get you goit you should get you goixt should get you goie not perfect bu
#
#
# iter :28000, loss:0.042707
# ect but should get you goixt should get you goixt should get you goit you goially long text to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you
#
#
# iter :28500, loss:0.041783
# xt should get you goie not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but shoul
#
#
# iter :29000, loss:0.040903
#  to test this. maybe not perfect but should getlyou goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goix
#
#
# iter :29500, loss:0.040061
# hould get you goie not perfect but should get you goit you goixt should get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but sho
#
#
# iter :30000, loss:0.039252
# t you goie not perfect but should get you goit you should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie
#
#
# iter :30500, loss:0.038483
#  to test this. maybe not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect burd get you goie
#
#
# iter :31000, loss:0.037746
# hould get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but
#
#
# iter :31500, loss:0.037036
# t you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit you should get you goie
#
#
# iter :32000, loss:0.036359
#  to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goifect but should get you goit you should get you goie
#
#
# iter :32500, loss:0.035706
# hould ge really long text to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should ge
#
#
# iter :33000, loss:0.035075
# t this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goi text to test this. may
#
#
# iter :33500, loss:0.034470
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect bu
#
#
# iter :34000, loss:0.033886
# ect but should get you goit you should get you goist should get you goie not perfect but should get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you
#
#
# iter :34500, loss:0.033319
# xt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you go
#
#
# iter :35000, loss:0.032774
#  to test this. maybe not perfect but should get you goie not perfect but should get you goi. not should get you goixt should get you goit you goit you goixt should get you goie not perfect but should
#
#
# iter :35500, loss:0.032247
# hould get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you should get you goist should get you goie not perfect but should get y
#
#
# iter :36000, loss:0.031734
# t you goie not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you go
#
#
# iter :36500, loss:0.031240
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goit you goie not p
#
#
# iter :37000, loss:0.030760
# ect but should get you goixt should get you goixt should get you goixt should get yoo goixt should get you goie not perfect but should get you goixt should get you goixt should get you goixt should ge
#
#
# iter :37500, loss:0.030292
# t you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not
#
#
# iter :38000, loss:0.029842
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get yo
#
#
# iter :38500, loss:0.029403
# hould get you goit you should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect b
#
#
# iter :39000, loss:0.028975
# xt should get you goie not perfect but should get you goie not perfect but should get you goit you goie not perfect but should get you goie not perfect but should get you goie not perfect but should g
#
#
# iter :39500, loss:0.028561
#  to test this. maybe not perfect but should get you goi text to test this. maybe not perfect but should get you goit you goixt should get you goie not perfect but should get you goie not perfect but s
#
#
# iter :40000, loss:0.028158
# ect but should get you goie not perfect but should get you goixt phould get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goi text to
#
#
# iter :40500, loss:0.027763
# t you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit you goito te test this. maybe not perfect but
#
#
# iter :41000, loss:0.027382
#  to test this. maybe not perfect but should get you goit you goixt perfect but should get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goixt shou
#
#
# iter :41500, loss:0.027009
# t goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goif you goi
#
#
# iter :42000, loss:0.026644
# t  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt ot xt xt sh
#
#
# iter :42500, loss:0.026291
#  to test this. maybe not perfect but should get you goie not perfect but should get you goist should get you goi text to test this. maybe not perfect but should get you goie not perfect but should get
#
#
# iter :43000, loss:0.025945
# ect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get y
#
#
# iter :43500, loss:0.025606
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt perfect but should get you goie not perfe
#
#
# iter :44000, loss:0.025277
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie
#
#
# iter :44500, loss:0.024955
# hiuld get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you
#
#
# iter :45000, loss:0.024638
# t you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt sh
#
#
# iter :45500, loss:0.024330
#  to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goi text to test this. maybe not perfect but should get
#
#
# iter :46000, loss:0.024028
# hould get you goie not pest you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goixt should get y
#
#
# iter :46500, loss:0.023730
# bt to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get
#
#
# iter :47000, loss:0.023439
#  to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goit you goie not p
#
#
# iter :47500, loss:0.023151
# esxt should get you goit you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit you goie not perfect but should get y
#
#
# iter :48000, loss:0.022863
# xt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get
#
#
# iter :48500, loss:0.022578
#  to test this. maybe not perfect but should get you goie not perxt should get you goixt should get you goit you goixt should get you goie not perfect but should get you goie not perfect but should get
#
#
# iter :49000, loss:0.022298
# hould get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie n
#
#
# iter :49500, loss:0.022023
# xt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect
#
#
# iter :50000, loss:0.021758
#  to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goit this. maybe not perfect but should get you goie not perfect but should get you goie no
#
#
# iter :50500, loss:0.021500
# t eo test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goi text to test this. maybe not
#
#
# iter :51000, loss:0.021249
# xt should get you goie not perfect but should get you goixt should get you goit you goixt should get you goie not perfect but should get you goit you goie not perfect but should get you goixt should g
#
#
# iter :51500, loss:0.021007
#  to test this. maybe not perfect but should get you goixt should get you goit you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie
#
#
# iter :52000, loss:0.020772
# ect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not per
#
#
# iter :52500, loss:0.020543
# xt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect
#
#
# iter :53000, loss:0.020322
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goi text to test this. maybe not perfect
#
#
# iter :53500, loss:0.020108
# hould get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should ge
#
#
# iter :54000, loss:0.019899
# xt should get you goi text to test this. maybe not perfect but should get you goixt should get you goixt should get you goixt should get you goit this. maybe not perfect but should get you goie not pe
#
#
# iter :54500, loss:0.019698
#  to test this. maybe not perfect but should get you goie not perfect but sybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get yo
#
#
# iter :55000, loss:0.019502
# hould get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get y
#
#
# iter :55500, loss:0.019310
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt shoul
#
#
# iter :56000, loss:0.019124
#  go test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goi. maybe not perfect but should get you goie not perf
#
#
# iter :56500, loss:0.018943
# hould get you goi text to test this. maybe not perfect but should get you goially long text to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but
#
#
# iter :57000, loss:0.018762
# xt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get
#
#
# iter :57500, loss:0.018587
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goi text to test this. maybe not perfect but should get you goixt should get
#
#
# iter :58000, loss:0.018413
# hould get you goixt should get you fest you goit you goit you goixt should get you goixt should get you goie not perfect but should get you goit you goie not perfect but should get you goie not perfec
#
#
# iter :58500, loss:0.018240
# xt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get
#
#
# iter :59000, loss:0.018070
#  to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goit you goixt shou
#
#
# iter :59500, loss:0.017902
# hould get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfec
#
#
# iter :60000, loss:0.017734
# e not perfect but should get you goi text to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goist should get you goixt should get you goixt sh
#
#
# iter :60500, loss:0.017570
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie
#
#
# iter :61000, loss:0.017407
# hould get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie n
#
#
# iter :61500, loss:0.017246
# t this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goie not perfect but
#
#
# iter :62000, loss:0.017088
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goist should get you goie not perfect bu
#
#
# iter :62500, loss:0.016933
# hould get you goie not perfect but should get you goixt should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfec
#
#
# iter :63000, loss:0.016779
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but shoul
#
#
# iter :63500, loss:0.016628
#  eoot maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt perfect but should get you goie not perfect but should get you goixt should get
#
#
# iter :64000, loss:0.016480
# hould get you goixt should get you goie not perfect but should get you goixt should get you goixt should get you goixt should get you goie not perfect but should get you goi text to test this. maybe n
#
#
# iter :64500, loss:0.016332
# xt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goixt shoul
#
#
# iter :65000, loss:0.016189
#  to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goi text to test th
#
#
# iter :65500, loss:0.016048
# ect but should get you goit you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goit you goie not
#
#
# iter :66000, loss:0.015908
# to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but
#
#
# iter :66500, loss:0.015771
#  to test this. maybe not perfect but should get you goi. not perfect but should get you goixt should get you goixt should get you goixt should get you goie not perfect but should get you goie not perf
#
#
# iter :67000, loss:0.015637
# ect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goially long text to test this. mayb
#
#
# iter :67500, loss:0.015504
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goit you goie not perfect but should get you goixt should get
#
#
# iter :68000, loss:0.015374
#  to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goist should get yo
#
#
# iter :68500, loss:0.015246
# hould get you goixt should get you goie not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you goixt should get you goixt should get you goi
#
#
# iter :69000, loss:0.015119
# t you goixt should get you goit you goit this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you go
#
#
# iter :69500, loss:0.014996
#  to test this. maybe not perfect but should get you goietsally long text to test this. maybe not perfect but should get you goit you goie not perfect but should get you goit this. maybe not perfect bu
#
#
# iter :70000, loss:0.014874
# ect but should get you goixt should get you goixt should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but
#
#
# iter :70500, loss:0.014753
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not pe
#
#
# iter :71000, loss:0.014635
#  to test this. maybe not perfect but should get you goixt should get you goixt should get you goixt should get you goie not perfect but should get you goit you goit this. maybe not perfect but should
#
#
# iter :71500, loss:0.014519
# tsxt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfec
#
#
# iter :72000, loss:0.014403
# e not perfect but should get you goie not perfect but should get you goie not perfect but u g text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should g
#
#
# iter :72500, loss:0.014291
#  to test this. maybe not perfect but should get you goixt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get yo
#
#
# iter :73000, loss:0.014180
# hbut should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you
#
#
# iter :73500, loss:0.014069
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not pe
#
#
# iter :74000, loss:0.013961
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goix
#
#
# iter :74500, loss:0.013855
# hould get you goie not perfect bhhould get you goixt should get you goie not perfect but should get you goit this. maybe not perfect but should get you goit you goie not should get you goixt should ge
#
#
# iter :75000, loss:0.013750
# to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie
#
#
# iter :75500, loss:0.013646
#  to test this. maybe not perfect but should get you goixt should get you goit you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but shou
#
#
# iter :76000, loss:0.013544
# ect but should get you goie not perfect but should get you goixt should get you goixt should get you goit this. maybe not perfect but should get you goixt should get you goie not perfect but should ge
#
#
# iter :76500, loss:0.013443
# t this. maybe not perfect but should get you goit you goist should get you goit you goixt should get you goixt should get you goie not perfect but should get you goit this. maybe not perfect but shoul
#
#
# iter :77000, loss:0.013344
#  to test this. maybe not perfect but should get you goie not perfect but should get you goi text to test this. maybe not perfect but should get you goie not perfect but should get you goixt should get
#
#
# iter :77500, loss:0.013246
# ect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goie not perfect but should
#
#
# iter :78000, loss:0.013149
# xt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goit you goie not
#
#
# iter :78500, loss:0.013053
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goie not perfect bu
#
#
# iter :79000, loss:0.012959
# hould get you goie not perfect but should get you goit you goixt should get you goit you goixt perfect but should get you goie not perfect but should get you goie not perfect but should get you goit t
#
#
# iter :79500, loss:0.012865
# xt should get you goit you goixt should get you goie not perfect but should get you goie not perfect but should get you goist should get you goit you goyong text to test this. maybe not perfect but sh
#
#
# iter :80000, loss:0.012773
#  to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goi text to test this. maybe not p
#
#
# iter :80500, loss:0.012682
# ect but should get you goist should get you goit this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should ge
#
#
# iter :81000, loss:0.012591
# xt should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit you goixt should get you goixt should get you go
#
#
# iter :81500, loss:0.012502
# ct but should get you goit you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect bu
#
#
# iter :82000, loss:0.012413
# ect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but
#
#
# iter :82500, loss:0.012325
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit you goie not perfect but should get you goixt should get you goie not perfect
#
#
# iter :83000, loss:0.012238
#  to test this. maybe not perfect but should get you goit you goie not perfect but should get you goit you goixt should get you goist should get you goie not perfect but should get you goie not perfect
#
#
# iter :83500, loss:0.012151
# ect but should get you goixt should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit this. m
#
#
# iter :84000, loss:0.012065
# t this. maybe not perfect but should get you goie not perfect but should get you goit you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get
#
#
# iter :84500, loss:0.011979
#  to test this. maybe not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goist s
#
#
# iter :85000, loss:0.011895
# ect but should get you goixt should get you goit this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you
#
#
# iter :85500, loss:0.011810
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you
#
#
# iter :86000, loss:0.011727
#  to test this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should get yo
#
#
# iter :86500, loss:0.011645
# ect but should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goixt should get you goit this. nou goit this. maybe not perfect but should get you
#
#
# iter :87000, loss:0.011563
# xt should get you goit you goixt should get you goit you goie not perfect but should get you goie not perfect but should get you goixt should get you goie not perfect but should get you goixt should g
#
#
# iter :87500, loss:0.011483
#  to test this. maybe not perfect but should get you goit long text to test this. maybe not perfect but should get you goit this. maybe not perfect but should get you goixt should get you goigo te test
#
#
# iter :88000, loss:0.011403
# hbut should get you goie not perfect but should get you goie not perfect but should get you goixt should get you goit this. maybe not perfect but should get you go test this. maybe not perfect but sho
#
#
# iter :88500, loss:0.011323
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not pe
#
#
# iter :89000, loss:0.011245
#  to test this. maybe not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should
#
#
# iter :89500, loss:0.011168
# ect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goially long text to test this. maybe not perfect but should get you goially long text to tes
#
#
# iter :90000, loss:0.011091
# xt should get you goie not perfect bto test this. maybe not perfect but should get you goixt perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get
#
#
# iter :90500, loss:0.011015
#  to test this. maybe not perfect but should get you goit you goit this. maybe not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you goit th
#
#
# iter :91000, loss:0.010940
# ect but should get you goixt should get you goit you goit this. maybe not perfect but should get you goie not perfect but should get you goi text to test this. maybe not perfect but should get you goi
#
#
# iter :91500, loss:0.010865
# t this. maybe not perfect but should get you goixt should get you goit you goie not perfect but should get you goixt should get you goit this. maybe not perfect but should get you goie not perfect but
#
#
# iter :92000, loss:0.010792
#  to test this. maybe not perfect but should get you goiatlsng text to test this. maybe not perfect but should get you goixt should get you goit you goit you goie not perfect but should get you goit th
#
#
# iter :92500, loss:0.010721
# est this. maybe not perfect but should get you goist should get you goit this. maybe not perfect but should get you goie not perfect but should get you goixt should get you goit this. maybe not perfec
#
#
# iter :93000, loss:0.010649
# t this. maybe not perfect but should get you goi. not should get you goie not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you goit this.
#
#
# iter :93500, loss:0.010580
#  to test this. maybe not perfect but should get you goixt should get you goie not perfect but should get you goixt should get you goixt should get you goixt should get you goie not perfect but should
#
#
# iter :94000, loss:0.010512
# ect but should get you goie not perfect but should get you goie not perfect but should get you goie not perfect but should get you goially long text to test this. maybe not perfect but should get you
#
#
# iter :94500, loss:0.010443
# t this. maybe not perfect but should get you goie not perfect but should get you goie not perfect but should get you goit this. maybe not perfect but should get you goixt should get you goit this. may
#
#
# iter :95000, loss:0.010377
#  to test this. maybe not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get you goit you goixt should get you goixt should get you goit this. ma
#
#
# iter :95500, loss:0.010312
# ect but should get you goit this. maybe not perfect but should get you goixt should get you goixt should get you goit you goit this. maybe not perfect but should get you goie not perfect but should ge
#
#
# iter :96000, loss:0.010248
# xt should get you goixt should get you goit this. maybe not perfect but should get you goixt should get you goixt should get you goit this. maybe not perfect but should get you goially long text to te
#
#
# iter :96500, loss:0.010184
#  to test this. maybe not perfect but should get you goie not perfect but should get you goit you goie not perfect but should get you goit this. maybe not perfect but should get you goie not perfect bu
#
#
# iter :97000, loss:0.010123
# ect but should get you goit this. maybe not perfect but should get you goit this. maybe not perfect but should get you goit this. maybe not perfect but should get you goie not perfect but should get y
#
#
# iter :97500, loss:0.010060

# %%
rnn.predict(data_reader, 'get', 50)
# Out:
# 'get text to test this. maybe not perfect but should g'
